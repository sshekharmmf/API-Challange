# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from ratelimit import limits, sleep_and_retry
# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
#Covert List to Pandas Series
citys=pd.Series(cities)
long=pd.Series(lngs)
lat=pd.Series(lats)

#Data Frame Pandas Series and Add new colums to 
city_data=pd.DataFrame({'city':citys,'Latitude':lat,'Longitude':long})
city_data["Temperature"] = ""
city_data["Humidity"] = ""
city_data["Cloudiness"] = ""
city_data["WindSpeed"] = ""

# %%
city_data=city_data.head(500)
city_data.head()
# Out:
#              city   Latitude   Longitude Temperature Humidity Cloudiness  \
# 0         rikitea -18.885246 -130.106168
# 1         ushuaia -86.471739  -44.531982
# 2         mataura -78.058854 -141.682309
# 3   oleksandrivka  45.879299   31.114333
# 4  guerrero negro  19.348730 -127.625444
#
#   WindSpeed
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = '8ee9bbd7f7ed6ddeb74857dbb1b6c841'
#api_key = api_keys.api_key

# Starting URL for Weather Map API Call
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&params&APPID={api_key}"

# %%
for index, row in city_data.iterrows():
    # get city, lat, lng from df
    # change location each iteration 
    cit=row['city']
    lat= row["Latitude"]
    lon=row['Longitude']
    # Use the search term:
   
    params= f"lat={lat}&lon={lon}"

    # make request and print url
    response = requests.get(url, params=params).json()
    


    # convert to json
    response2 = json.dumps(response)
    # print(json.dumps(name_address, indent=4, sort_keys=True))
    #time.sleep(1)
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        city_data.loc[index, "Temperature"] = response['main']['temp_max']
        city_data.loc[index, "Humidity"] =response['main']['humidity']
        city_data.loc[index, "Cloudiness"] = response['clouds']['all']
        city_data.loc[index, "WindSpeed"] =response['wind']['speed']
        print(f'{ cit}, City_number {index} found data updating table')
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# rikitea, City_number 0 found data updating table
# ushuaia, City_number 1 found data updating table
# mataura, City_number 2 found data updating table
# oleksandrivka, City_number 3 found data updating table
# guerrero negro, City_number 4 found data updating table
# dapaong, City_number 5 found data updating table
# thaton, City_number 6 found data updating table
# wewak, City_number 7 found data updating table
# saint-augustin, City_number 8 found data updating table
# cabo san lucas, City_number 9 found data updating table
# taolanaro, City_number 10 found data updating table
# silchar, City_number 11 found data updating table
# barbar, City_number 12 found data updating table
# barentsburg, City_number 13 found data updating table
# puerto ayora, City_number 14 found data updating table
# seydi, City_number 15 found data updating table
# hilo, City_number 16 found data updating table
# taoudenni, City_number 17 found data updating table
# chikwawa, City_number 18 found data updating table
# dunedin, City_number 19 found data updating table
# leningradskiy, City_number 20 found data updating table
# maryville, City_number 21 found data updating table
# port alfred, City_number 22 found data updating table
# gejiu, City_number 23 found data updating table
# port lincoln, City_number 24 found data updating table
# castro, City_number 25 found data updating table
# avarua, City_number 26 found data updating table
# tuktoyaktuk, City_number 27 found data updating table
# qaanaaq, City_number 28 found data updating table
# busselton, City_number 29 found data updating table
# komsomolskiy, City_number 30 found data updating table
# mahebourg, City_number 31 found data updating table
# georgetown, City_number 32 found data updating table
# hermanus, City_number 33 found data updating table
# kapaa, City_number 34 found data updating table
# sitka, City_number 35 found data updating table
# vila franca do campo, City_number 36 found data updating table
# kodiak, City_number 37 found data updating table
# mar del plata, City_number 38 found data updating table
# ahipara, City_number 39 found data updating table
# bosaso, City_number 40 found data updating table
# gaozhou, City_number 372 found data updating table
# turayf, City_number 373 found data updating table
# cervo, City_number 374 found data updating table
# cap-aux-meules, City_number 375 found data updating table
# taylor, City_number 376 found data updating table
# adrasmon, City_number 377 found data updating table
# kalomo, City_number 378 found data updating table
# albertville, City_number 379 found data updating table
# azimur, City_number 380 found data updating table
# santa clarita, City_number 381 found data updating table
# ati, City_number 382 found data updating table
# grindavik, City_number 383 found data updating table
# lac du bonnet, City_number 384 found data updating table
# ugoofaaru, City_number 385 found data updating table
# oistins, City_number 386 found data updating table
# dawlatabad, City_number 387 found data updating table
# grand forks, City_number 388 found data updating table
# nizhniy tagil, City_number 389 found data updating table
# calatrava, City_number 390 found data updating table
# kloulklubed, City_number 391 found data updating table
# narsaq, City_number 392 found data updating table
# westport, City_number 393 found data updating table
# muli, City_number 394 found data updating table
# sur, City_number 395 found data updating table
# harper, City_number 396 found data updating table
# itarema, City_number 397 found data updating table
# lata, City_number 398 found data updating table
# hunza, City_number 399 found data updating table
# okhotsk, City_number 400 found data updating table
# sao gabriel da cachoeira, City_number 401 found data updating table
# alamos, City_number 402 found data updating table
# tessalit, City_number 403 found data updating table
# entre rios, City_number 404 found data updating table
# aquiraz, City_number 405 found data updating table
# luba, City_number 406 found data updating table
# longlac, City_number 407 found data updating table
# labrea, City_number 408 found data updating table
# orlik, City_number 409 found data updating table
# obluche, City_number 410 found data updating table
# taltal, City_number 411 found data updating table
# sao felix do xingu, City_number 412 found data updating table
# pittsfield, City_number 413 found data updating table
# vao, City_number 414 found data updating table
# kichera, City_number 415 found data updating table
# aykhal, City_number 416 found data updating table
# altenstadt, City_number 417 found data updating table
# asau, City_number 418 found data updating table
# huilong, City_number 419 found data updating table
# hue, City_number 420 found data updating table
# podbrdo, City_number 421 found data updating table
# camapua, City_number 422 found data updating table
# beatrice, City_number 423 found data updating table
# luanda, City_number 424 found data updating table
# shirvan, City_number 425 found data updating table
# cap malheureux, City_number 426 found data updating table
# burgeo, City_number 427 found data updating table
# polyarnyy, City_number 428 found data updating table
# erenhot, City_number 429 found data updating table
# berberati, City_number 430 found data updating table
# te anau, City_number 431 found data updating table
# kommunisticheskiy, City_number 432 found data updating table
# kondinskoye, City_number 433 found data updating table
# novyy urgal, City_number 434 found data updating table
# fallbrook, City_number 435 found data updating table
# montepuez, City_number 436 found data updating table
# houma, City_number 437 found data updating table
# kaeo, City_number 438 found data updating table
# quatre cocos, City_number 439 found data updating table
# bokoro, City_number 440 found data updating table
# ukhta, City_number 441 found data updating table
# gari, City_number 442 found data updating table
# santa maria, City_number 443 found data updating table
# kavieng, City_number 444 found data updating table
# boyolangu, City_number 445 found data updating table
# yomou, City_number 446 found data updating table
# talara, City_number 447 found data updating table
# mahadday weyne, City_number 448 found data updating table
# mbanza-ngungu, City_number 449 found data updating table
# tungor, City_number 450 found data updating table
# guider, City_number 451 found data updating table
# klaksvik, City_number 452 found data updating table
# biltine, City_number 453 found data updating table
# mount isa, City_number 454 found data updating table
# santa cruz, City_number 455 found data updating table
# moree, City_number 456 found data updating table
# koshurnikovo, City_number 457 found data updating table
# sakakah, City_number 458 found data updating table
# puerto suarez, City_number 459 found data updating table
# vanimo, City_number 460 found data updating table
# puri, City_number 461 found data updating table
# srednekolymsk, City_number 462 found data updating table
# nador, City_number 463 found data updating table
# pascagoula, City_number 464 found data updating table
# tonkino, City_number 465 found data updating table
# mackay, City_number 466 found data updating table
# olinda, City_number 467 found data updating table
# broome, City_number 468 found data updating table
# kurskaya, City_number 469 found data updating table
# malanje, City_number 470 found data updating table
# longkou, City_number 471 found data updating table
# apac, City_number 472 found data updating table
# vostok, City_number 473 found data updating table
# baker city, City_number 474 found data updating table
# opuwo, City_number 475 found data updating table
# havelock, City_number 476 found data updating table
# murwillumbah, City_number 477 found data updating table
# rawannawi, City_number 478 found data updating table
# nampula, City_number 479 found data updating table
# sao joao do piaui, City_number 480 found data updating table
# angoche, City_number 481 found data updating table
# hambantota, City_number 482 found data updating table
# artyk, City_number 483 found data updating table
# vanderhoof, City_number 484 found data updating table
# grosseto, City_number 485 found data updating table
# dehloran, City_number 486 found data updating table
# ituni, City_number 487 found data updating table
# tecoanapa, City_number 488 found data updating table
# west wendover, City_number 489 found data updating table
# lorengau, City_number 490 found data updating table
# pisco, City_number 491 found data updating table
# zyryanovsk, City_number 492 found data updating table
# kushima, City_number 493 found data updating table
# mogadishu, City_number 494 found data updating table
# sola, City_number 495 found data updating table
# evensk, City_number 496 found data updating table
# banda aceh, City_number 497 found data updating table
# nurlat, City_number 498 found data updating table
# farias brito, City_number 499 found data updating table

# %%
city_data.head()
city_data.to_csv("City_data.csv")

# %%
plt.suptitle(f'Latitude Vrs Tem {time.ctime()}')
plt.scatter(city_data['Latitude'],city_data['Temperature'],alpha=0.85,c='blue',edgecolor = 'black', label = 'Temp')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.text(43,40," Latitude.")
plt.legend()
plt.grid()
plt.show()

plt.savefig('Temp.jpeg')

# %%
plt.suptitle(f'Latitude Vrs Humidity {time.ctime()}')
plt.scatter(city_data['Latitude'],city_data['Humidity'],alpha=0.85,c='blue',edgecolor = 'black', label = 'Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.text(43,90," Latitude.")
plt.ylim(-1,110)
plt.legend()
plt.grid()
plt.show()

plt.savefig("Humidity.jpeg")

# %%
plt.suptitle(f'Latitude Vrs Cloudiness {time.ctime()}')
plt.scatter(city_data['Latitude'],city_data['Cloudiness'],alpha=0.85,c='blue',edgecolor = 'black', label = 'Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness)')
plt.text(43,40," Latitude.")
plt.legend()
plt.grid()
plt.show()

plt.savefig('Cloudiness.jpeg')

# %%
plt.suptitle(f'Latitude Vrs WindSpeed {time.ctime()}')
plt.scatter(city_data['Latitude'],city_data['WindSpeed'],alpha=0.85,c='blue',edgecolor = 'black', label = 'WindSpeedp')
plt.xlabel('Latitude')
plt.ylabel('WindSpeed)')
plt.text(43,40," Latitude.")
plt.legend()
plt.grid()
plt.show()

plt.savefig('WindSpeed.jpeg')
